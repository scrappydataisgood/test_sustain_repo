# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/mnt/Wet_yield_prediction/Organized_Work/Datasets/hybrid_planned_yield_dataset_all_seasons.csv').drop(columns = ['Unnamed: 0'])

print(display(df))
# Out:
#     Field_Name  CO2_kg_per_Ha  Crop_Protection_Application_Doses  \
# 0      M6I2035        -220.35                               14.0
# 1      M6I2036        3847.21                               18.0
# 2      M6I2037         415.52                               13.0
# 3      M6I2009         724.51                                9.0
# 4      M6I2010         502.10                                9.0
# ..         ...            ...                                ...
# 915   M6I21197        -239.89                               15.0
# 916   M6I21199         314.80                               17.0
# 917   M6I21200        -312.82                               19.0
# 918   M6I21201         485.73                               17.0
# 919   M6I21202        -522.49                               18.0
#
#      Soil_Organic_Matter  Yield_kg_per_Ha  Total_N  Total_P  Total_K  Season  \
# 0               2.500000      3049.333333    205.5     48.0     48.0  WINTER
# 1               2.500000      3575.055556    492.0    216.0    216.0  WINTER
# 2               2.500000      3116.200000    198.0     60.0     60.0  WINTER
# 3               2.500000      7678.888889    202.4     95.2     96.0  WINTER
# 4               2.500000      7756.363636    179.4     95.2     90.0  WINTER
# ..                   ...              ...      ...      ...      ...     ...
# 915             2.597851      4073.493976     92.0      0.0      0.0  WINTER
# 916             3.120000      6969.677419    184.0      0.0      0.0  WINTER
# 917             2.930000      6969.636364     92.0      0.0      0.0  WINTER
# 918             3.240000      7954.666667    207.0      0.0      0.0  WINTER
# 919             4.250000      6392.846154    184.0      0.0      0.0  WINTER
#
#          Hybrid  Planned_Yield_kg_per_ha
# 0    DKB335PRO3                   4700.0
# 1    DKB335PRO3                   4700.0
# 2    DKB335PRO3                   4700.0
# 3    AG8480PRO3                   6300.0
# 4    AG8480PRO3                   6300.0
# ..          ...                      ...
# 915  DKB360PRO3                   5400.0
# 916  DKB360PRO3                   5400.0
# 917  DKB360PRO3                   5400.0
# 918  DKB360PRO3                   5800.0
# 919  DKB360PRO3                   5400.0
#
# [920 rows x 11 columns]
# None

# %%
plt.figure()
df['Hybrid'].value_counts().hist()
plt.xlabel('Number of Fields Containing Particular Hybrid')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Fields Containing Particular Hybrid')
# Out:
# Text(0.5, 1.0, 'Histogram of Number of Fields Containing Particular Hybrid')

# %%
# summer + winter subset by hybrid
# -cutoff: 20 rows
# -create linear reg for each bucket, record R squared
