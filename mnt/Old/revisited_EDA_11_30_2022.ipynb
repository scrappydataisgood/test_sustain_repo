# %%
import os
cwd = os.path.abspath('')
os.chdir('/mnt')
files = os.listdir(cwd)

# %%
import pandas as pd
import scipy as sp
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats

df = pd.read_csv('/mnt/Datasets/merged_dataframe_11_30_2022.csv').drop(columns = ['Unnamed: 0'])

corr_matrix = df.corr()
plt.figure(figsize = (10, 7))
sn.heatmap(corr_matrix, annot = True, annot_kws={"fontsize":18})
sn.set(font_scale = 1)
plt.show()
# Out:
#                                    N_as_Nitrate_kg_per_Ha  \
# N_as_Nitrate_kg_per_Ha                           1.000000
# P_as_Phosphorus_kg_per_Ha                        0.400832
# K_as_Potassium_kg_per_Ha                         0.619080
# Soil_Organic_Matter                             -0.067518
# Yield_Mass_kg_Per_Ha                            -0.006247
# CO2_kg_Emissions_per_Ha                         -0.168765
# Total_Water_Applied_mm                           0.111340
# Crop_Protection_Application_Doses                0.006557
#
#                                    P_as_Phosphorus_kg_per_Ha  \
# N_as_Nitrate_kg_per_Ha                              0.400832
# P_as_Phosphorus_kg_per_Ha                           1.000000
# K_as_Potassium_kg_per_Ha                            0.428963
# Soil_Organic_Matter                                -0.049244
# Yield_Mass_kg_Per_Ha                                0.008658
# CO2_kg_Emissions_per_Ha                            -0.057618
# Total_Water_Applied_mm                             -0.087810
# Crop_Protection_Application_Doses                  -0.008011
#
#                                    K_as_Potassium_kg_per_Ha  \
# N_as_Nitrate_kg_per_Ha                             0.619080
# P_as_Phosphorus_kg_per_Ha                          0.428963
# K_as_Potassium_kg_per_Ha                           1.000000
# Soil_Organic_Matter                               -0.073064
# Yield_Mass_kg_Per_Ha                               0.013154
# CO2_kg_Emissions_per_Ha                           -0.089305
# Total_Water_Applied_mm                            -0.024705
# Crop_Protection_Application_Doses                 -0.074891
#
#                                    Soil_Organic_Matter  Yield_Mass_kg_Per_Ha  \
# N_as_Nitrate_kg_per_Ha                       -0.067518             -0.006247
# P_as_Phosphorus_kg_per_Ha                    -0.049244              0.008658
# K_as_Potassium_kg_per_Ha                     -0.073064              0.013154
# Soil_Organic_Matter                           1.000000              0.025191
# Yield_Mass_kg_Per_Ha                          0.025191              1.000000
# CO2_kg_Emissions_per_Ha                      -0.543721              0.036565
# Total_Water_Applied_mm                        0.146377              0.069410
# Crop_Protection_Application_Doses            -0.021151             -0.084927
#
#                                    CO2_kg_Emissions_per_Ha  \
# N_as_Nitrate_kg_per_Ha                           -0.168765
# P_as_Phosphorus_kg_per_Ha                        -0.057618
# K_as_Potassium_kg_per_Ha                         -0.089305
# Soil_Organic_Matter                              -0.543721
# Yield_Mass_kg_Per_Ha                              0.036565
# CO2_kg_Emissions_per_Ha                           1.000000
# Total_Water_Applied_mm                           -0.118089
# Crop_Protection_Application_Doses                 0.309642
#
#                                    Total_Water_Applied_mm  \
# N_as_Nitrate_kg_per_Ha                           0.111340
# P_as_Phosphorus_kg_per_Ha                       -0.087810
# K_as_Potassium_kg_per_Ha                        -0.024705
# Soil_Organic_Matter                              0.146377
# Yield_Mass_kg_Per_Ha                             0.069410
# CO2_kg_Emissions_per_Ha                         -0.118089
# Total_Water_Applied_mm                           1.000000
# Crop_Protection_Application_Doses                0.106214
#
#                                    Crop_Protection_Application_Doses
# N_as_Nitrate_kg_per_Ha                                      0.006557
# P_as_Phosphorus_kg_per_Ha                                  -0.008011
# K_as_Potassium_kg_per_Ha                                   -0.074891
# Soil_Organic_Matter                                        -0.021151
# Yield_Mass_kg_Per_Ha                                       -0.084927
# CO2_kg_Emissions_per_Ha                                     0.309642
# Total_Water_Applied_mm                                      0.106214
# Crop_Protection_Application_Doses                           1.000000
# None

# %%
df = pd.read_csv('/mnt/Datasets/merged_dataframe_with_elements_11_30_2022.csv').drop(columns = ['Unnamed: 0'])

corr_matrix = df.corr()
plt.figure(figsize = (12, 8))
sn.heatmap(corr_matrix, annot = True)
sn.set(font_scale = 1)
plt.show()
