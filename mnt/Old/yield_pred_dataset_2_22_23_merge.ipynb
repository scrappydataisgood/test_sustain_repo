# %%
import pandas as pd

# %%
df = pd.read_csv('/mnt/Datasets/merged_df_2_22_23.csv')

print(display(df))
# Out:
#       Unnamed: 0 Data Relatório               Nome grower    Técnico de Campo  \
# 0              0     2021-03-22       JOAO EMILIO ROCHETO  AMARILDO GONÇALVES
# 1              1     2021-03-22       JOAO EMILIO ROCHETO  AMARILDO GONÇALVES
# 2              2     2021-03-22       JOAO EMILIO ROCHETO  AMARILDO GONÇALVES
# 3              3     2021-03-22       JOAO EMILIO ROCHETO  AMARILDO GONÇALVES
# 4              4     2021-03-22  CELISMAR MARTINS CAETANO     ADEMIR BERNARDI
# ...          ...            ...                       ...                 ...
# 1264        1264     2022-05-16            ONORATO PALUDO    ANDERSON/GUSTAVO
# 1265        1265     2022-05-16            ONORATO PALUDO    ANDERSON/GUSTAVO
# 1266        1266     2022-05-16            ONORATO PALUDO    ANDERSON/GUSTAVO
# 1267        1267     2022-05-16            ONORATO PALUDO    ANDERSON/GUSTAVO
# 1268        1268     2022-05-16            ONORATO PALUDO    ANDERSON/GUSTAVO
#
# ...
