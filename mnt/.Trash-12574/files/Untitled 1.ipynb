# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/mnt/Datasets/merged_dataframe_with_elements_11_30_2022.csv').drop(columns = ['Unnamed: 0'])
print(display(df))
# Out:
#      N_as_Nitrate_kg_per_Ha  P_as_Phosphorus_kg_per_Ha  \
# 0                    6000.0                        0.0
# 1                    6600.0                        0.0
# 2                    6000.0                        0.0
# 3                    2600.0                    11960.0
# 4                    2600.0                    11960.0
# ..                      ...                        ...
# 378                  1700.0                    12580.0
# 379                  1700.0                    12580.0
# 380                  1600.0                    12800.0
# 381                  9000.0                        0.0
# 382                  9000.0                        0.0
#
#      K_as_Potassium_kg_per_Ha Field_Name  Soil_Organic_Matter  \
# 0                      6000.0    M2I2001             2.500000
# 1                      6600.0    M2I2002             2.500000
# 2                      6000.0    M2I2003             2.500000
# 3                         0.0    M2I2008             2.500000
# 4                         0.0    M2I2009             2.500000
# ..                        ...        ...                  ...
# 378                       0.0    M8V2148             4.881250
# 379                       0.0    M8V2150             5.907407
# 380                       0.0    M8V2151             2.500000
# 381                    6000.0    M8V2152             2.500000
# 382                    6000.0    M8V2153             2.500000
#
#      Yield_Mass_kg_Per_Ha  CO2_kg_Emissions_per_Ha
# 0             4786.900000                   349.85
# 1             5234.476190                   488.41
# 2             4358.380952                   462.26
# 3             4960.000000                  1060.97
# 4             4477.614679                   490.60
# ..                    ...                      ...
# 378           2681.750000                  -350.22
# 379           2829.610390                  -233.82
# 380           3215.714286                  -665.62
# 381           1100.000000                   429.34
# 382            628.000000                   406.39
#
# [383 rows x 7 columns]
# None

# %%
plt.hist(df['P_as_Phosphorus_kg_per_Ha'])
# Out:
# (array([ 65.,   6.,  46., 118., 123.,  20.,   0.,   0.,   1.,   4.]),
#  array([    0.,  2552.,  5104.,  7656., 10208., 12760., 15312., 17864.,
#         20416., 22968., 25520.]),
#  <BarContainer object of 10 artists>)
