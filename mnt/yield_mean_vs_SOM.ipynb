# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_winter = pd.read_csv('/mnt/Datasets/df_3_27_23_winter_parent_compounds.csv').drop(columns = ['Unnamed: 0'])
print(display(df_winter))
# Out:
#      CO2_kg_per_Ha  Crop_Protection_Application_Doses  Soil_Organic_Matter  \
# 0          -220.35                               14.0             2.500000
# 1          3847.21                               18.0             2.500000
# 2           415.52                               13.0             2.500000
# 3           724.51                                9.0             2.500000
# 4           502.10                                9.0             2.500000
# ..             ...                                ...                  ...
# 500        -239.89                               15.0             2.597851
# 501         314.80                               17.0             3.120000
# 502        -312.82                               19.0             2.930000
# 503         485.73                               17.0             3.240000
# 504        -522.49                               18.0             4.250000
#
#      Yield_kg_per_Ha  N_as_Urea_kg_per_Ha  N_as_Nitrate_kg_per_Ha  \
# ...

# %%
df_winter_0_to_05_yield = df_winter[df_winter['Soil_Organic_Matter'] < .5]['Yield_kg_per_Ha'].mean()
df_winter_05_to_1_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= .5) & (df_winter['Soil_Organic_Matter'] < 1)]['Yield_kg_per_Ha'].mean()
df_winter_1_to_15_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 1) & (df_winter['Soil_Organic_Matter'] < 1.5)]['Yield_kg_per_Ha'].mean()
df_winter_15_to_2_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 1.5) & (df_winter['Soil_Organic_Matter'] < 2)]['Yield_kg_per_Ha'].mean()
df_winter_2_to_25_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 2) & (df_winter['Soil_Organic_Matter'] < 2.5)]['Yield_kg_per_Ha'].mean()
df_winter_25_to_3_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 2.5) & (df_winter['Soil_Organic_Matter'] < 3)]['Yield_kg_per_Ha'].mean()
df_winter_3_to_35_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 3) & (df_winter['Soil_Organic_Matter'] < 3.5)]['Yield_kg_per_Ha'].mean()
df_winter_35_to_4_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 3.5) & (df_winter['Soil_Organic_Matter'] < 4)]['Yield_kg_per_Ha'].mean()
df_winter_4_to_45_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 4) & (df_winter['Soil_Organic_Matter'] < 4.5)]['Yield_kg_per_Ha'].mean()
df_winter_45_to_5_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 4.5) & (df_winter['Soil_Organic_Matter'] < 5)]['Yield_kg_per_Ha'].mean()
df_winter_5_to_55_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 5) & (df_winter['Soil_Organic_Matter'] < 5.5)]['Yield_kg_per_Ha'].mean()
df_winter_55_to_6_yield = df_winter[(df_winter['Soil_Organic_Matter'] >= 5.5) & (df_winter['Soil_Organic_Matter'] < 6)]['Yield_kg_per_Ha'].mean()

df_winter_yield_means = [df_winter_0_to_05_yield, df_winter_05_to_1_yield, df_winter_1_to_15_yield, \
                      df_winter_15_to_2_yield, df_winter_2_to_25_yield, df_winter_25_to_3_yield, \
                      df_winter_3_to_35_yield, df_winter_35_to_4_yield, df_winter_4_to_45_yield, \
                      df_winter_45_to_5_yield, df_winter_5_to_55_yield, df_winter_55_to_6_yield]

plt.figure(figsize = (5,5))
plt.scatter([.25, .75, 1.25, 1.75, 2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25, 5.75], df_winter_yield_means)
plt.xlabel('Soil Organic Matter, Increments of .5')
plt.ylabel('Mean Yield (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Winter)')
plt.show()

print(len(df_winter[df_winter['Soil_Organic_Matter'] < .5]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= .5) & (df_winter['Soil_Organic_Matter'] < 1)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 1) & (df_winter['Soil_Organic_Matter'] < 1.5)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 1.5) & (df_winter['Soil_Organic_Matter'] < 2)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 2) & (df_winter['Soil_Organic_Matter'] < 2.5)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 2.5) & (df_winter['Soil_Organic_Matter'] < 3)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 3) & (df_winter['Soil_Organic_Matter'] < 3.5)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 3.5) & (df_winter['Soil_Organic_Matter'] < 4)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 4) & (df_winter['Soil_Organic_Matter'] < 4.5)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 4.5) & (df_winter['Soil_Organic_Matter'] < 5)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 5) & (df_winter['Soil_Organic_Matter'] < 5.5)]['Yield_kg_per_Ha']))
print(len(df_winter[(df_winter['Soil_Organic_Matter'] >= 5.5) & (df_winter['Soil_Organic_Matter'] < 6)]['Yield_kg_per_Ha']))

df_winter_yield_means = df_winter_yield_means[4:8]
print(len(df_winter_yield_means))

plt.figure(figsize = (5,5))
plt.scatter([2.25, 2.75, 3.25, 3.75], df_winter_yield_means)
plt.xlabel('Soil Organic Matter, Increments of .5')
plt.ylabel('Mean Yield (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Summer, Minimum 20 data points)')
plt.show()
# Out:
# 1
# 0
# 1
# 18
# 40
# 352
# 52
# 30
# 5
# 1
# 2
# 3
# 4

# %%
df_winter = df_winter.sort_values('Soil_Organic_Matter').reset_index(drop = True)
print(display(df_winter))

df_winter_0_SOM_median = df_winter[:50]['Soil_Organic_Matter'].median()
df_winter_0_yield_mean = df_winter[:50]['Yield_kg_per_Ha'].mean()
df_winter_1_SOM_median = df_winter[50:100]['Soil_Organic_Matter'].median()
df_winter_1_yield_mean = df_winter[50:100]['Yield_kg_per_Ha'].mean()
df_winter_2_SOM_median = df_winter[100:150]['Soil_Organic_Matter'].median()
df_winter_2_yield_mean = df_winter[100:150]['Yield_kg_per_Ha'].mean()
df_winter_3_SOM_median = df_winter[150:200]['Soil_Organic_Matter'].median()
df_winter_3_yield_mean = df_winter[150:200]['Yield_kg_per_Ha'].mean()
df_winter_4_SOM_median = df_winter[200:250]['Soil_Organic_Matter'].median()
df_winter_4_yield_mean = df_winter[200:250]['Yield_kg_per_Ha'].mean()
df_winter_5_SOM_median = df_winter[250:300]['Soil_Organic_Matter'].median()
df_winter_5_yield_mean = df_winter[250:300]['Yield_kg_per_Ha'].mean()
df_winter_6_SOM_median = df_winter[300:350]['Soil_Organic_Matter'].median()
df_winter_6_yield_mean = df_winter[300:350]['Yield_kg_per_Ha'].mean()
df_winter_7_SOM_median = df_winter[350:400]['Soil_Organic_Matter'].median()
df_winter_7_yield_acmean = df_winter[350:400]['Yield_kg_per_Ha'].mean()
df_winter_8_SOM_median = df_winter[400:450]['Soil_Organic_Matter'].median()
df_winter_8_yield_mean = df_winter[400:450]['Yield_kg_per_Ha'].mean()
df_winter_9_SOM_median = df_winter[450:505]['Soil_Organic_Matter'].median()
df_winter_9_yield_mean = df_winter[450:505]['Yield_kg_per_Ha'].mean()

SOM_list = [df_winter_0_SOM_median, df_winter_1_SOM_median, df_winter_2_SOM_median, df_winter_3_SOM_median, df_winter_4_SOM_median, \
           df_winter_5_SOM_median, df_winter_6_SOM_median, df_winter_7_SOM_median, df_winter_8_SOM_median, df_winter_9_SOM_median]
yield_list = [df_winter_0_yield_mean, df_winter_1_yield_mean, df_winter_2_yield_mean, df_winter_3_yield_mean, df_winter_4_yield_mean, \
             df_winter_5_yield_mean, df_winter_6_yield_mean, df_winter_7_yield_mean, df_winter_8_yield_mean, df_winter_9_yield_mean]

plt.figure(figsize = (5,5))
plt.scatter(SOM_list, yield_list)
plt.xlabel('Soil Organic Matter, Median per Bucket')
plt.ylabel('Mean Yield per Bucket (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Winter, 10 Buckets)')
plt.show()
# Out:
#      CO2_kg_per_Ha  Crop_Protection_Application_Doses  Soil_Organic_Matter  \
# 0          2261.29                               17.0             0.400000
# 1          2562.38                               24.0             1.467568
# 2          1306.64                               12.0             1.500000
# 3           157.50                               17.0             1.518280
# 4          2560.11                               21.0             1.519231
# ..             ...                                ...                  ...
# 500        -430.58                               21.0             5.430769
# 501        -510.27                               18.0             5.460000
# 502        -553.42                               22.0             5.580000
# 503        -486.74                               23.0             5.630000
# 504        -644.77                               21.0             5.746667
#
#      Yield_kg_per_Ha  N_as_Urea_kg_per_Ha  N_as_Nitrate_kg_per_Ha  \
# ...

# %%
df_winter = pd.read_csv('/mnt/Datasets/df_3_27_23_winter_parent_compounds.csv').drop(columns = ['Unnamed: 0'])

df_winter = df_winter.sort_values('Soil_Organic_Matter').reset_index(drop = True)
print(display(df_winter))

df_winter_0_SOM_median = df_winter[:85]['Soil_Organic_Matter'].median()
df_winter_0_yield_mean = df_winter[:85]['Yield_kg_per_Ha'].mean()
df_winter_1_SOM_median = df_winter[85:170]['Soil_Organic_Matter'].median()
df_winter_1_yield_mean = df_winter[85:170]['Yield_kg_per_Ha'].mean()
df_winter_2_SOM_median = df_winter[170:255]['Soil_Organic_Matter'].median()
df_winter_2_yield_mean = df_winter[170:255]['Yield_kg_per_Ha'].mean()
df_winter_3_SOM_median = df_winter[255:340]['Soil_Organic_Matter'].median()
df_winter_3_yield_mean = df_winter[255:340]['Yield_kg_per_Ha'].mean()
df_winter_4_SOM_median = df_winter[340:425]['Soil_Organic_Matter'].median()
df_winter_4_yield_mean = df_winter[340:425]['Yield_kg_per_Ha'].mean()
df_winter_5_SOM_median = df_winter[425:]['Soil_Organic_Matter'].median()
df_winter_5_yield_mean = df_winter[425:]['Yield_kg_per_Ha'].mean()


SOM_list = [df_winter_0_SOM_median, df_winter_1_SOM_median, df_winter_2_SOM_median, df_winter_3_SOM_median, df_winter_4_SOM_median, df_winter_5_SOM_median]
yield_list = [df_winter_0_yield_mean, df_winter_1_yield_mean, df_winter_2_yield_mean, df_winter_3_yield_mean, df_winter_4_yield_mean, df_winter_5_yield_mean]

plt.figure(figsize = (5,5))
plt.scatter(SOM_list, yield_list)
plt.xlabel('Soil Organic Matter, Median per Bucket')
plt.ylabel('Mean Yield per Bucket (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Winter, 5 Buckets)')
plt.show()
# Out:
#      CO2_kg_per_Ha  Crop_Protection_Application_Doses  Soil_Organic_Matter  \
# 0          2261.29                               17.0             0.400000
# 1          2562.38                               24.0             1.467568
# 2          1306.64                               12.0             1.500000
# 3           157.50                               17.0             1.518280
# 4          2560.11                               21.0             1.519231
# ..             ...                                ...                  ...
# 500        -430.58                               21.0             5.430769
# 501        -510.27                               18.0             5.460000
# 502        -553.42                               22.0             5.580000
# 503        -486.74                               23.0             5.630000
# 504        -644.77                               21.0             5.746667
#
#      Yield_kg_per_Ha  N_as_Urea_kg_per_Ha  N_as_Nitrate_kg_per_Ha  \
# ...

# %%
df_summer = pd.read_csv('/mnt/Datasets/df_3_27_23_summer_parent_compounds.csv').drop(columns = ['Unnamed: 0'])
print(display(df_summer))
# Out:
#      CO2_kg_per_Ha  Crop_Protection_Application_Doses  Soil_Organic_Matter  \
# 0          -246.74                               14.0             3.690000
# 1           219.02                               20.0             3.380000
# 2           860.73                               18.0             2.681429
# 3           799.98                               17.0             2.681429
# 4          1426.97                               25.0             2.316250
# ..             ...                                ...                  ...
# 410         449.67                               16.0             2.690000
# 411       -1035.15                               15.0             5.380000
# 412       -1092.21                               13.0             5.380000
# 413        -427.99                               15.0             3.750000
# 414         417.60                               20.0             2.860000
#
#      Yield_kg_per_Ha  N_as_Urea_kg_per_Ha  N_as_Nitrate_kg_per_Ha  \
# ...

# %%
df_summer_0_to_05_yield = df_summer[df_summer['Soil_Organic_Matter'] < .5]['Yield_kg_per_Ha'].mean()
df_summer_05_to_1_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= .5) & (df_summer['Soil_Organic_Matter'] < 1)]['Yield_kg_per_Ha'].mean()
df_summer_1_to_15_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 1) & (df_summer['Soil_Organic_Matter'] < 1.5)]['Yield_kg_per_Ha'].mean()
df_summer_15_to_2_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 1.5) & (df_summer['Soil_Organic_Matter'] < 2)]['Yield_kg_per_Ha'].mean()
df_summer_2_to_25_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 2) & (df_summer['Soil_Organic_Matter'] < 2.5)]['Yield_kg_per_Ha'].mean()
df_summer_25_to_3_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 2.5) & (df_summer['Soil_Organic_Matter'] < 3)]['Yield_kg_per_Ha'].mean()
df_summer_3_to_35_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 3) & (df_summer['Soil_Organic_Matter'] < 3.5)]['Yield_kg_per_Ha'].mean()
df_summer_35_to_4_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 3.5) & (df_summer['Soil_Organic_Matter'] < 4)]['Yield_kg_per_Ha'].mean()
df_summer_4_to_45_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 4) & (df_summer['Soil_Organic_Matter'] < 4.5)]['Yield_kg_per_Ha'].mean()
df_summer_45_to_5_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 4.5) & (df_summer['Soil_Organic_Matter'] < 5)]['Yield_kg_per_Ha'].mean()
df_summer_5_to_55_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 5) & (df_summer['Soil_Organic_Matter'] < 5.5)]['Yield_kg_per_Ha'].mean()
df_summer_55_to_6_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 5.5) & (df_summer['Soil_Organic_Matter'] < 6)]['Yield_kg_per_Ha'].mean()

df_summer_yield_means = [df_summer_0_to_05_yield, df_summer_05_to_1_yield, df_summer_1_to_15_yield, \
                      df_summer_15_to_2_yield, df_summer_2_to_25_yield, df_summer_25_to_3_yield, \
                      df_summer_3_to_35_yield, df_summer_35_to_4_yield, df_summer_4_to_45_yield, \
                      df_summer_45_to_5_yield, df_summer_5_to_55_yield, df_summer_55_to_6_yield]

print(df_summer['Soil_Organic_Matter'].max())



plt.figure(figsize = (5,5))
plt.scatter([.25, .75, 1.25, 1.75, 2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25, 5.75], df_summer_yield_means)
plt.xlabel('Soil Organic Matter, Increments of .5')
plt.ylabel('Mean Yield (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Summer)')
plt.show()

print(len(df_summer[df_summer['Soil_Organic_Matter'] < .5]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= .5) & (df_summer['Soil_Organic_Matter'] < 1)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 1) & (df_summer['Soil_Organic_Matter'] < 1.5)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 1.5) & (df_summer['Soil_Organic_Matter'] < 2)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 2) & (df_summer['Soil_Organic_Matter'] < 2.5)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 2.5) & (df_summer['Soil_Organic_Matter'] < 3)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 3) & (df_summer['Soil_Organic_Matter'] < 3.5)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 3.5) & (df_summer['Soil_Organic_Matter'] < 4)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 4) & (df_summer['Soil_Organic_Matter'] < 4.5)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 4.5) & (df_summer['Soil_Organic_Matter'] < 5)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 5) & (df_summer['Soil_Organic_Matter'] < 5.5)]['Yield_kg_per_Ha']))
print(len(df_summer[(df_summer['Soil_Organic_Matter'] >= 5.5) & (df_summer['Soil_Organic_Matter'] < 6)]['Yield_kg_per_Ha']))

df_summer_yield_means = df_summer_yield_means[3:9]
print(len(df_summer_yield_means))

plt.figure(figsize = (5,5))
plt.scatter([1.75, 2.25, 2.75, 3.25, 3.75, 4.25], df_summer_yield_means)
plt.xlabel('Soil Organic Matter, Increments of .5')
plt.ylabel('Mean Yield (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Summer, Minimum 20 data points)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_341/1063463674.py in <module>
# ----> 1 df_summer_0_to_05_yield = df_summer[df_summer['Soil_Organic_Matter'] < .5]['Yield_kg_per_Ha'].mean()
#       2 df_summer_05_to_1_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= .5) & (df_summer['Soil_Organic_Matter'] < 1)]['Yield_kg_per_Ha'].mean()
#       3 df_summer_1_to_15_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 1) & (df_summer['Soil_Organic_Matter'] < 1.5)]['Yield_kg_per_Ha'].mean()
#       4 df_summer_15_to_2_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 1.5) & (df_summer['Soil_Organic_Matter'] < 2)]['Yield_kg_per_Ha'].mean()
#       5 df_summer_2_to_25_yield = df_summer[(df_summer['Soil_Organic_Matter'] >= 2) & (df_summer['Soil_Organic_Matter'] < 2.5)]['Yield_kg_per_Ha'].mean()
#
# NameError: name 'df_summer' is not defined

# %%
df_summer = df_summer.sort_values('Soil_Organic_Matter').reset_index(drop = True)
print(display(df_summer))

df_summer_0_SOM_median = df_summer[:50]['Soil_Organic_Matter'].median()
df_summer_0_yield_mean = df_summer[:50]['Yield_kg_per_Ha'].mean()
df_summer_1_SOM_median = df_summer[50:100]['Soil_Organic_Matter'].median()
df_summer_1_yield_mean = df_summer[50:100]['Yield_kg_per_Ha'].mean()
df_summer_2_SOM_median = df_summer[100:150]['Soil_Organic_Matter'].median()
df_summer_2_yield_mean = df_summer[100:150]['Yield_kg_per_Ha'].mean()
df_summer_3_SOM_median = df_summer[150:200]['Soil_Organic_Matter'].median()
df_summer_3_yield_mean = df_summer[150:200]['Yield_kg_per_Ha'].mean()
df_summer_4_SOM_median = df_summer[200:250]['Soil_Organic_Matter'].median()
df_summer_4_yield_mean = df_summer[200:250]['Yield_kg_per_Ha'].mean()
df_summer_5_SOM_median = df_summer[250:300]['Soil_Organic_Matter'].median()
df_summer_5_yield_mean = df_summer[250:300]['Yield_kg_per_Ha'].mean()
df_summer_6_SOM_median = df_summer[300:350]['Soil_Organic_Matter'].median()
df_summer_6_yield_mean = df_summer[300:350]['Yield_kg_per_Ha'].mean()
df_summer_7_SOM_median = df_summer[350:400]['Soil_Organic_Matter'].median()
df_summer_7_yield_mean = df_summer[350:400]['Yield_kg_per_Ha'].mean()
df_summer_8_SOM_median = df_summer[400:450]['Soil_Organic_Matter'].median()
df_summer_8_yield_mean = df_summer[400:450]['Yield_kg_per_Ha'].mean()
df_summer_9_SOM_median = df_summer[450:505]['Soil_Organic_Matter'].median()
df_summer_9_yield_mean = df_summer[450:505]['Yield_kg_per_Ha'].mean()

SOM_list = [df_summer_0_SOM_median, df_summer_1_SOM_median, df_summer_2_SOM_median, df_summer_3_SOM_median, df_summer_4_SOM_median, \
           df_summer_5_SOM_median, df_summer_6_SOM_median, df_summer_7_SOM_median, df_summer_8_SOM_median, df_summer_9_SOM_median]
yield_list = [df_summer_0_yield_mean, df_summer_1_yield_mean, df_summer_2_yield_mean, df_summer_3_yield_mean, df_summer_4_yield_mean, \
             df_summer_5_yield_mean, df_summer_6_yield_mean, df_summer_7_yield_mean, df_summer_8_yield_mean, df_summer_9_yield_mean]

plt.figure(figsize = (5,5))
plt.scatter(SOM_list, yield_list)
plt.xlabel('Soil Organic Matter, Median per Bucket')
plt.ylabel('Mean Yield per Bucket (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Summer, 10 Buckets)')
plt.show()
# Out:
#      CO2_kg_per_Ha  Crop_Protection_Application_Doses  Soil_Organic_Matter  \
# 0          1628.68                               13.0             0.150000
# 1          2381.35                               19.0             0.386889
# 2           744.04                               15.0             0.590000
# 3           802.59                               15.0             0.590333
# 4          1640.06                               12.0             0.950000
# ..             ...                                ...                  ...
# 410       -1427.07                               19.0             5.300000
# 411       -1035.15                               15.0             5.380000
# 412       -1092.21                               13.0             5.380000
# 413        -577.56                               14.0             5.500000
# 414        -233.82                               21.0             5.907407
#
#      Yield_kg_per_Ha  N_as_Urea_kg_per_Ha  N_as_Nitrate_kg_per_Ha  \
# ...

# %%
df_full = pd.concat([df_summer, df_winter])

df_full_0_to_05_yield = df_full[df_full['Soil_Organic_Matter'] < .5]['Yield_kg_per_Ha'].mean()
df_full_05_to_1_yield = df_full[(df_full['Soil_Organic_Matter'] >= .5) & (df_full['Soil_Organic_Matter'] < 1)]['Yield_kg_per_Ha'].mean()
df_full_1_to_15_yield = df_full[(df_full['Soil_Organic_Matter'] >= 1) & (df_full['Soil_Organic_Matter'] < 1.5)]['Yield_kg_per_Ha'].mean()
df_full_15_to_2_yield = df_full[(df_full['Soil_Organic_Matter'] >= 1.5) & (df_full['Soil_Organic_Matter'] < 2)]['Yield_kg_per_Ha'].mean()
df_full_2_to_25_yield = df_full[(df_full['Soil_Organic_Matter'] >= 2) & (df_full['Soil_Organic_Matter'] < 2.5)]['Yield_kg_per_Ha'].mean()
df_full_25_to_3_yield = df_full[(df_full['Soil_Organic_Matter'] >= 2.5) & (df_full['Soil_Organic_Matter'] < 3)]['Yield_kg_per_Ha'].mean()
df_full_3_to_35_yield = df_full[(df_full['Soil_Organic_Matter'] >= 3) & (df_full['Soil_Organic_Matter'] < 3.5)]['Yield_kg_per_Ha'].mean()
df_full_35_to_4_yield = df_full[(df_full['Soil_Organic_Matter'] >= 3.5) & (df_full['Soil_Organic_Matter'] < 4)]['Yield_kg_per_Ha'].mean()
df_full_4_to_45_yield = df_full[(df_full['Soil_Organic_Matter'] >= 4) & (df_full['Soil_Organic_Matter'] < 4.5)]['Yield_kg_per_Ha'].mean()
df_full_45_to_5_yield = df_full[(df_full['Soil_Organic_Matter'] >= 4.5) & (df_full['Soil_Organic_Matter'] < 5)]['Yield_kg_per_Ha'].mean()
df_full_5_to_55_yield = df_full[(df_full['Soil_Organic_Matter'] >= 5) & (df_full['Soil_Organic_Matter'] < 5.5)]['Yield_kg_per_Ha'].mean()
df_full_55_to_6_yield = df_full[(df_full['Soil_Organic_Matter'] >= 5.5) & (df_full['Soil_Organic_Matter'] < 6)]['Yield_kg_per_Ha'].mean()

df_full_yield_means = [df_full_0_to_05_yield, df_full_05_to_1_yield, df_full_1_to_15_yield, \
                      df_full_15_to_2_yield, df_full_2_to_25_yield, df_full_25_to_3_yield, \
                      df_full_3_to_35_yield, df_full_35_to_4_yield, df_full_4_to_45_yield, \
                      df_full_45_to_5_yield, df_full_5_to_55_yield, df_full_55_to_6_yield]

plt.figure(figsize = (5,5))
plt.scatter([.25, .75, 1.25, 1.75, 2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25, 5.75], df_full_yield_means)
plt.xlabel('Soil Organic Matter, Increments of .5')
plt.ylabel('Mean Yield (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Full Year)')
plt.show()

print(len(df_full[df_full['Soil_Organic_Matter'] < .5]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= .5) & (df_full['Soil_Organic_Matter'] < 1)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 1) & (df_full['Soil_Organic_Matter'] < 1.5)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 1.5) & (df_full['Soil_Organic_Matter'] < 2)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 2) & (df_full['Soil_Organic_Matter'] < 2.5)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 2.5) & (df_full['Soil_Organic_Matter'] < 3)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 3) & (df_full['Soil_Organic_Matter'] < 3.5)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 3.5) & (df_full['Soil_Organic_Matter'] < 4)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 4) & (df_full['Soil_Organic_Matter'] < 4.5)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 4.5) & (df_full['Soil_Organic_Matter'] < 5)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 5) & (df_full['Soil_Organic_Matter'] < 5.5)]['Yield_kg_per_Ha']))
print(len(df_full[(df_full['Soil_Organic_Matter'] >= 5.5) & (df_full['Soil_Organic_Matter'] < 6)]['Yield_kg_per_Ha']))

df_full_yield_means = df_full_yield_means[3:9]
print(len(df_full_yield_means))

plt.figure(figsize = (5,5))
plt.scatter([1.75, 2.25, 2.75, 3.25, 3.75, 4.25], df_full_yield_means)
plt.xlabel('Soil Organic Matter, Increments of .5')
plt.ylabel('Mean Yield (kg/ha)')
plt.title('Mean Yield vs. Soil Organic Matter (Full Year, Minimum 20 data points)')
plt.show()
# Out:
# 3
# 3
# 4
# 42
# 105
# 523
# 108
# 74
# 29
# 18
# 6
# 5
# 6
